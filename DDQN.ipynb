# %%
import gym 
import torch
import matplotlib.pyplot as plt
import random
from collections import deque
import copy
import IPython
    
class DQN(torch.nn.Module):
    def __init__(self, input_size, output_size, l1, l2, lr):
        super().__init__()
        self.brain = torch.nn.Sequential(
            torch.nn.Linear(input_size, l1),
            torch.nn.ReLU(),
            torch.nn.Linear(l1, l2),
            torch.nn.ReLU(),
            torch.nn.Linear(l2, output_size)
        )
        self.loss_fn = torch.nn.MSELoss()
        self.optimizer = torch.optim.Adam(self.brain.parameters(), lr=lr)
        self.eps = 1
        
    def evaluate_q(self, state):
        return self.brain(state)
    
    def act_on_q(self, q):
        if random.random() < self.eps:
            action = random.randint(0, 1)
        else:
            action = q.argmax().item()
        return action
    
    def forward(self, state):
        q = self.evaluate_q(torch.Tensor(state))
        action = self.act_on_q(q)
        return action
        
    def learn(self, x, y):
        loss = self.loss_fn(x, y)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        return loss.item()

def play_one_step(env, agent):
    state1 = env.env.state
    q = agent.evaluate_q(torch.Tensor(state1))
    action = agent.act_on_q(q)
    state2, reward, done, info = env.step(action)
    return (state1, action, reward, state2, done, q, info)
            
def sample_experience(replay_buffer, batch_size=32):
    minibatch = random.sample(replay_buffer, batch_size)
    state1, action, reward, state2, done = (torch.Tensor(z) for z in zip(*minibatch))
    return state1, action, reward, state2, done

def update_agent(agent, target_brain, exp, gamma=0.95):
    state1, action, reward, state2, done = exp
    q1 = agent.evaluate_q(state1)
    with torch.no_grad():
        q2 = agent.evaluate_q(state2)
        q2_action = torch.max(q2, dim=1).indices
        target_q = target_brain(state2)
        
    q_max = target_q.gather(dim=1, index=q2_action.view(-1, 1)).view(-1)
    x = q1.gather(dim=1, index=action.long().view(-1, 1)).view(-1)
    y = reward + (1 - done) * gamma * q_max
    loss = agent.learn(x, y)
    return loss

def play_n_episodes(env, policy, n=100):
    rewards = []
    for _ in range(n):
        state = env.reset()
        total_reward = 0
        while True:
            action = policy(state)
            new_state, reward, done, info = env.step(action)
            state = new_state
            total_reward += reward
            if done:
                break
        rewards.append(total_reward)
    return rewards

def naive_policy(state):
    if state[3] > 0:
        return 1
    else:
        return 0

# %%
env = gym.make("CartPole-v1")

agent = DQN(input_size=4, output_size=2, l1=100, l2=100, lr=0.00025)
target_brain = copy.deepcopy(agent.brain)

batch_size = 32
max_epochs = 2000
sync_freq = 500
buffer_len = 5000
gamma = 0.99

replay_buffer = deque(maxlen=buffer_len)
losses = []
rewards = []
total_steps = 0

# %%
for epoch in range(1, max_epochs+1):
    env.reset()
    total_reward = 0
    while True:
        total_steps += 1
        (state1, action, reward, state2, done, q, info) = play_one_step(env, agent)
        replay_buffer.append((state1, action, reward, state2, done))
        total_reward += reward
        
        if len(replay_buffer) > batch_size:
            exp = sample_experience(replay_buffer, batch_size=batch_size)
            loss = update_agent(agent, target_brain, exp, gamma=gamma)
            losses.append(loss)
                    
            if agent.eps > 0.1:
                agent.eps -= 0.0001
        
        if total_steps % sync_freq == 0:
            target_brain.load_state_dict(agent.brain.state_dict())
            
        if done:
            break
            
    print(epoch, total_reward)
    rewards.append(total_reward)
    IPython.display.clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-51b248b1d37c> in <module>
#      10         if len(replay_buffer) > batch_size:
#      11             exp = sample_experience(replay_buffer, batch_size=batch_size)
# ---> 12             loss = update_agent(agent, target_brain, exp, gamma=gamma)
#      13             losses.append(loss)
#      14
#
# <ipython-input-81-2c3a29d0eb42> in update_agent(agent, target_brain, exp, gamma)
#      66     x = q1.gather(dim=1, index=action.long().view(-1, 1)).view(-1)
#      67     y = reward + (1 - done) * gamma * q_max
# ---> 68     loss = agent.learn(x, y)
#      69     return loss
#      70
#
# <ipython-input-81-2c3a29d0eb42> in learn(self, x, y)
#      40         self.optimizer.zero_grad()
#      41         loss.backward()
# ---> 42         self.optimizer.step()
#      43         return loss.item()
#      44
#
# ~\Anaconda3\lib\site-packages\torch\optim\adam.py in step(self, closure)
#      94                 # Decay the first and second moment running average coefficient
#      95                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
# ---> 96                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#      97                 if amsgrad:
#      98                     # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

# %%
def max_q_policy(state):
    q = agent.evaluate_q(torch.Tensor(state))
    return q.argmax().item()

steps = play_n_episodes(env, max_q_policy)
print(sum(steps)/len(steps))
plt.plot(steps)
# Out:
# 421.28

# %%
plt.plot(rewards)

# %%
steps = play_n_episodes(env, naive_policy)
plt.plot(steps)
